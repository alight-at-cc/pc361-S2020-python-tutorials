# %% [markdown]
# <h2 align="center">Iterative Methods for Solving Equations</h2>

# %% [markdown]
# Solving differential equations numerically can often be much faster than doing so analytically.  The Euler-Cromer method provides a simple solution to solving equations.  Read pages 1-5 of <a href="https://moodle.swarthmore.edu/mod/resource/view.php?id=180998">the PDF provided on Moodle</a> for the basic background information on this method, which we'll use in today's lesson.
#
# Once you've finished that, look at the code below.

# %%
#import lines
# %matplotlib inline
import matplotlib.pyplot as plt

def EulerCromer(tfinal, dt, v0):
    '''Euler-Cromer method, takes tfinal (final time), dt (time step), 
    and v0 (initial velocity) as arguments'''
    t = 0 # initial time
    y = 0 # initial position
    a = 0 # no acceleration
    v = v0 # initial velocity

    # Set up position, velocity, and time arrays, initially with one
    # entry each:
    time = [t] 
    ypos = [y] 
    yvel = [v]
    
    while t <= tfinal - dt: # Update variables using Eqs. (1) & (2) 
        v = v + a * dt 
        # Note that this uses the *new* v we just defined in prev. step
        y = y + v * dt

        # Add updated variables to the lists 
        yvel.append(v) 
        ypos.append(y)

        # Increment time 
        t = t + dt 
        time.append(t)
        
    #plot results
    # %matplotlib inline
    import matplotlib.pyplot as mp
    plt.subplot(2,1,1)
    plt.plot(time,yvel)
    plt.title("Velocity")
    plt.subplot(2,1,2)
    plt.plot(time,ypos)
    plt.title("Position")
    plt.tight_layout(pad=2)
    plt.show()
    
EulerCromer(10,0.1,50)

# %% [markdown]
# These plots show the velocity and position of an object moving at zero accceleration.  This is not particularly interesting.  But the nice thing about solving equations numerically is that it makes it relatively simple to add other effects, which in some cases can be difficult to build into an analytic solution.
#
# *Note:*  In the exercises below, you will write successively more realistic versions of the algorithm above.  For each case, write a new function, copying and pasting code as necessary from your previous cell(s).  Give each new function a different name so that there is no confusion about which function your code is calling.
#
# **Exercise 1** Create a modified version of the code above that includes Earth's gravity.  The acceleration, $a$, will no longer be a constant.  The force of gravity on an object near earth is given by $F = G m M_E / r^2$ where $G = 6.674 \times 10^{-11}$ in SI units and the mass of Earth is $M_E = 5.972 \times 10^{24}$ kg.  Use the radius of the Earth, $R_E = y=6.371 \times 10^6$ m as your starting `y`.  Write your code as a function that takes as an argument an initial velocity, a time step and a final time.

# %%
def EulerCromer(tfinal, dt, v0):
    '''Euler-Cromer method, takes tfinal (final time), dt (time step), 
    and v0 (initial velocity) as arguments'''
    G = 6.674E-11
    Re = 6.371E6
    Me = 5.972E24
        
    t = 0 # initial time
    y = 0 # initial position
    a = 0 # no acceleration
    v = v0 # initial velocity

    # Set up position, velocity, and time arrays, initially with one
    # entry each:
    time = [t] 
    ypos = [y] 
    yvel = [v]
    
    while t <= tfinal - dt: # Update variables using Eqs. (1) & (2) 
        a = -1*G*Me/(y+Re)**2
        v = v + a * dt 
        # Note that this uses the *new* v we just defined in prev. step
        y = y + v * dt

        # Add updated variables to the lists 
        yvel.append(v) 
        ypos.append(y)

        # Increment time 
        t = t + dt 
        time.append(t)
        
    #plot results
    # %matplotlib inline
    import matplotlib.pyplot as mp
    plt.subplot(2,1,1)
    plt.plot(time,yvel)
    plt.title("Velocity")
    plt.subplot(2,1,2)
    plt.plot(time,ypos)
    plt.title("Position")
    plt.tight_layout(pad=2)
    plt.show()
    
EulerCromer(10,0.1,50)

# %% [markdown]
# **Exercise 2** We are launching a rocket powered by an Estes 6-3 rocket engine.  Assume the mass of the rocket is constant (because the weight of the propellent << weight of the rocket).  The Estes rocket has total impulse of $10 N s$ over $1.6s$ and our rocket weighs $100 g$ including the engine.  Have the function stop when the rocket lands. Print the maximum height and time at which it landed as well as the velocity and position curves you printed before.  Design your function such that we can use other values for mass, thrust and time of firing.  You can assume initial velocity is 0.

# %%
def EulerCromer(tfinal, dt, mass, thrust, trocket):
    '''Euler-Cromer method, takes tfinal (final time), dt (time step), 
    and v0 (initial velocity) as arguments'''
    G = 6.674E-11
    Re = 6.371E6
    Me = 5.972E24
        
    t = 0 # initial time
    y = 0 # initial position
    a = 0 # no acceleration
    v = 0 # initial velocity

    # Set up position, velocity, and time arrays, initially with one
    # entry each:
    time = [t] 
    ypos = [y] 
    yvel = [v]
    ymax = 0
    
    while t <= tfinal - dt and y>=0: # Update variables using Eqs. (1) & (2) 
        if t < trocket:
            a = -1*G*Me/(y+Re)**2 + thrust/mass
        else:
            a = -1*G*Me/(y+Re)**2
        v = v + a * dt 
        # Note that this uses the *new* v we just defined in prev. step
        y = y + v * dt

        # Add updated variables to the lists 
        yvel.append(v) 
        ypos.append(y)

        # Increment time 
        t = t + dt 
        time.append(t)
        if y > ymax:
            ymax = y
        
    print(t)
    print(ymax)
    #plot results
    # %matplotlib inline
    import matplotlib.pyplot as mp
    plt.subplot(2,1,1)
    plt.plot(time,yvel)
    plt.title("Velocity")
    plt.subplot(2,1,2)
    plt.plot(time,ypos)
    plt.title("Position")
    plt.tight_layout(pad=2)
    plt.show()
    
EulerCromer(100,0.01,0.1, 10/1.6, 1.6)
# Out:
# 19.540000000000255
# 429.2185536618356

# %% [markdown]
# **Exercise 3** Modify your code to now include drag.  Quadratic air drag in one dimension can be approximated as an additional acceleration, with a magnitude of $ a_{drag} = \frac{1}{2m} C_D \rho A v^2$ (where $C_D = 0.5$ and $\rho=1.3$ approximately on Earth) and a direction that is *opposite the direction of the velocity*.  Your function should take $A$, the cross-sectional area of the object as an argument.  For your final test case to turn in, use $A = 0.01\, m^2$, but play around with other areas to see the effect.

# %%
import numpy as np

def EulerCromer(tfinal, dt, mass, thrust, trocket, A):
    '''Euler-Cromer method, takes tfinal (final time), dt (time step), 
    and v0 (initial velocity) as arguments'''
    G = 6.674E-11
    Re = 6.371E6
    Me = 5.972E24
    Cd = 0.5
    rho = 1.3
        
    t = 0 # initial time
    y = 0 # initial position
    a = 0 # no acceleration
    v = 0 # initial velocity

    # Set up position, velocity, and time arrays, initially with one
    # entry each:
    time = [t] 
    ypos = [y] 
    yvel = [v]
    ymax = 0
    
    while t <= tfinal - dt and y>=0: # Update variables using Eqs. (1) & (2) 
        if t < trocket:
            a = -1*G*Me/(y+Re)**2 + thrust/mass - 1 / (2*mass) * Cd * rho * A * v**2 * np.sign(v)
        else:
            a = -1*G*Me/(y+Re)**2
        v = v + a * dt 
        # Note that this uses the *new* v we just defined in prev. step
        y = y + v * dt

        # Add updated variables to the lists 
        yvel.append(v) 
        ypos.append(y)

        # Increment time 
        t = t + dt 
        time.append(t)
        if y > ymax:
            ymax = y
        
    print(t)
    print(ymax)
    #plot results
    # %matplotlib inline
    import matplotlib.pyplot as mp
    plt.subplot(2,1,1)
    plt.plot(time,yvel)
    plt.title("Velocity")
    plt.subplot(2,1,2)
    plt.plot(time,ypos)
    plt.title("Position")
    plt.tight_layout(pad=2)
    plt.show()
    
EulerCromer(100,0.01,0.1, 10/1.6, 1.6, 0.01)
# Out:
# 10.55999999999982
# 121.501010659

# %% [markdown]
# **Exercise 4** Implement the Euler-Cromer method to solve for the motion of a mass on a frictionless surface that is connected to a wall by an ideal Hooke's Law spring.  Formulate your equations in terms of the normalized displacement, $x/L$, so that your initial position will be in the interval $[0,1)$.  Plot the position and velocity as functions of time, and make a "phase portrait" plot of $v(t)$ versus $x(t)$.  Check your result against what you know about the simple harmonic oscillator.  What happens if you choose a time step that is too large (use a number that does not divide evenly by the oscillation period)?

# %%
def EulerCromerSHO(tfinal, dt, x0=0.01, v0=0., w0 = 100):
    '''Euler-Cromer method, takes tfinal (final time), dt (time step), 
    and v0 (initial velocity) as arguments'''
    
    
    print("Natural frequency %2.2f"%(w0))
    print("Number of oscillations per time step: 1/w_osc*dt = %5.3f"%(1./(w0*dt)))
    
    t = 0 # initial time
    y = 0 # initial position
    x = x0 # initial position (cannot be larger than L)
    v = v0 # initial velocity
    a = -w0**2*x # initial acceleration
    
    # Set up position, velocity, and time arrays (actually lists, for easy appending), 
    # initially with one entry each:
    time = [t] 
    xpos = [x] 
    xvel = [v]
    xacc = [a]
    
    while t <= tfinal - dt: # Update variables using Eqs. (1) & (2) 
        v = v + a * dt #increment velocity
        # Note that this uses the *new* v we just defined in prev. step
        x = x + v * dt #increment position
        a = -w0**2*x #increment acceleration
        
        # Add updated variables to the lists 
        xvel.append(v) 
        xpos.append(x)
        xacc.append(a)

        # Increment time 
        t = t + dt 
        time.append(t)
        
    return np.array(time),np.array(xpos),np.array(xvel)


def plot_osc(t,x,v):
    #plot results
    plt.subplot(2,1,1)
    plt.plot(t,v)
    plt.title("Velocity")
    plt.subplot(2,1,2)
    plt.plot(t,x)
    plt.title("Position")
    plt.tight_layout(pad=2)
    plt.show()
    plt.plot(x,v,)
    #ax = plt.gca()
    #ax.set_aspect(x.max()/v.max())
    plt.show()

w0 = 1.
dt = 0.1/w0 # number of oscillations per time step = w0*dt
#Try $\Delta t = pi/\omega_0$ to see blow up
t,x,v = EulerCromerSHO(20,dt,x0=0.01,w0=w0)
plot_osc(t,x,v)
# Out:
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 10.000

# %% [markdown]
# **Exercise 5** Real springs can't maintain a linear (Hooke's Law) restoring force as the extension or compression gets to be of the order of the equilibrium length of the spring. As first step towards a more realistic model, add an additional force term $\epsilon\omega_0^2 x^3$ to your oscillator, making sure the sign is such that the force gets stronger as the displacement increases (a "hard" spring).  Plot the position on the same axes as the position of a SHO with the same natural frequency for each of the following cases:
#
# * $\epsilon=1$, $x_0/L$ = 0.1
# * $\epsilon=1$, $x_0/L$ = 0.9
# * $\epsilon=10$, $x_0/L$ = 0.1
# * $\epsilon=10$, $x_0/L$ = 0.9
#
# Do the same for the velocity.  Note the distortion from sinusoidal motion as the nonlinearity becomes significant.  What happens to the frequency as the amplitude increases?  What does this mean for the time step you must choose?

# %%
def EulerCromerDuffing(tfinal, dt, x0=0.01, v0=0., w0=1., epsilon=0.1):
    '''Euler-Cromer method, takes tfinal (final time), dt (time step), 
    and v0 (initial velocity) as arguments'''
    
    
    print("Natural frequency %2.2f"%(w0))
    print("Number of oscillations per time step: 1/w_osc*dt = %5.3f"%(1./(w0*dt)))
    
    t = 0 # initial time
    x = x0 # initial position (in units of L)
    v = v0 # initial velocity
    a = -w0**2*x * (1 + epsilon*x**2) # initial acceleration

    # Set up position, velocity, and time arrays (actually lists, for easy appending), 
    # initially with one entry each:
    time = [t] 
    xpos = [x] 
    xvel = [v]
    xacc = [a]
    
    while t <= tfinal - dt: # Update variables using Eqs. (1) & (2) 
        a = -w0**2*x * (1 + epsilon*x**2)#increment acceleration
        v = v + a * dt #increment velocity
        # Note that this uses the *new* v we just defined in prev. step
        x = x + v * dt #increment position
        
        
        # Add updated variables to the lists 
        xvel.append(v) 
        xpos.append(x)
        xacc.append(a)

        # Increment time 
        t = t + dt 
        time.append(t)
        
    return np.array(time),np.array(xpos),np.array(xvel)


def plot_twoosc(t1,x1,v1,t2,x2,v2):
    #plot results
    plt.subplot(2,1,1)
    plt.plot(t,x/x.max())
    plt.plot(t,xnl/xnl.max())
    plt.xlabel("Time (s)")
    plt.title("Position (norm)")
    plt.subplot(2,1,2)
    plt.plot(tnl,v/v.max())
    plt.plot(tnl,vnl/vnl.max())
    plt.xlabel("Time (s)")
    plt.title("Velocity (norm)")
    plt.tight_layout(pad=2)
    plt.show()
    plt.plot(x1/x1.max(),v1/v1.max(),)
    plt.plot(x2/x2.max(),v2/v2.max())
    plt.xlabel("Position (norm)")
    plt.ylabel("Velocity (norm)")
    plt.show()

w0 = 1.
dt = 0.1/w0 # number of oscillations per time step = w0*dt
#Try $\Delta t = pi/\omega_0$ to see blow up

t,x,v = EulerCromerSHO(20,dt,x0=0.01,w0=w0)

# make plots for each case:
print("\n-- epsilon=1;  x_0/L = 0.1 --")
tnl,xnl,vnl = EulerCromerDuffing(20,dt,w0=w0,x0=0.1,epsilon=1)
plot_twoosc(t,x,v,tnl,xnl,vnl)
print("\n-- epsilon=1;  x_0/L = 0.9 --")
tnl,xnl,vnl = EulerCromerDuffing(20,dt,w0=w0,x0=0.9,epsilon=1)
plot_twoosc(t,x,v,tnl,xnl,vnl)
print("\n-- epsilon=10;  x_0/L = 0.1 --")
tnl,xnl,vnl = EulerCromerDuffing(20,dt,w0=w0,x0=0.1,epsilon=10)
plot_twoosc(t,x,v,tnl,xnl,vnl)
print("\n-- epsilon=10;  x_0/L = 0.9 --")
tnl,xnl,vnl = EulerCromerDuffing(20,dt,w0=w0,x0=0.9,epsilon=10)
plot_twoosc(t,x,v,tnl,xnl,vnl)
# Out:
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 10.000
#
# -- epsilon=1;  x_0/L = 0.1 --
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 10.000
# -- epsilon=1;  x_0/L = 0.9 --
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 10.000
# -- epsilon=10;  x_0/L = 0.1 --
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 10.000
# -- epsilon=10;  x_0/L = 0.9 --
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 10.000

# %% [markdown]
# **(Optional) Animation** It's much more fun to present your dynamics if you can make a movie out of them.  For example:

# %%
import matplotlib.animation
from IPython.display import HTML

t = np.linspace(0,2*np.pi)
x = np.sin(t)

fig, ax = plt.subplots()
ax.axis([0,2*np.pi,-1,1])
l, = ax.plot([],[],'o')
plt.close(fig)

def animate(i):
    l.set_data(t[i], x[i])

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(t))

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgf0a092fb60cd476bbdb367d79eda05c7">
#     <br>
#     <input id="_anim_sliderf0a092fb60cd476bbdb367d79eda05c7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animf0a092fb60cd476bbdb367d79eda05c7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animf0a092fb60cd476bbdb367d79eda05c7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectf0a092fb60cd476bbdb367d79eda05c7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf0a092fb60cd476bbdb367d79eda05c7";
#     var slider_id = "_anim_sliderf0a092fb60cd476bbdb367d79eda05c7";
#     var loop_select_id = "_anim_loop_selectf0a092fb60cd476bbdb367d79eda05c7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAGcVJREFUeJzt3X9sVfX9x/HXpXcwmFPaSbH3e7tA\
# uZfSluJFbqXmuznaUjtxu3yZVcqYVgq7zpEsssTZb9QuJGOUadicmCU3I3KdSatjW9s4KRSZIyFu\
# zR1tpuLMXWi1vbtgC+38MemF6/3+8Y0369oyGL0/PpfnIzHhnvM5975PNPeZe+7laInFYjEBAGCY\
# GakeAACA/wQBAwAYiYABAIxEwAAARiJgAAAjETAAgJEIGADASAQMAGAkAgYAMBIBAwAYiYABAIxE\
# wAAARiJgAAAjETAAgJEIGADASAQMAGAkAgYAMBIBAwAYiYABAIxEwAAARiJgAAAjETAAgJEIGADA\
# SAQMAGAkAgYAMBIBAwAYiYABAIxEwAAARiJgAAAjETAAgJGSFrCGhgbl5uZq6dKlk+6PxWL6zne+\
# I4fDoWXLlun48ePxfX6/X06nU06nU36/P1kjAwDSWNICdt9996mzs3PK/QcOHFAwGFQwGJTP59MD\
# DzwgSTp79qy2b9+uP/7xj+ru7tb27ds1MjKSrLEBAGkqaQG79dZblZOTM+X+9vZ23XvvvbJYLCov\
# L9fo6KjC4bAOHjyo6upq5eTkKDs7W9XV1RcNIQDg6pA234GFQiHl5+fHH9vtdoVCoSm3AwCubtZU\
# D/CJWCw2YZvFYply+2R8Pp98Pp8k6S9/+YuWLFkyvUMCQIbr7+/X8PBwqse4JGkTMLvdroGBgfjj\
# wcFB2Ww22e12vfLKK+O2r1q1atLn8Hq98nq9kiS3261AIJDIkQEg47jd7lSPcMnS5hKix+PRs88+\
# q1gspj/84Q+67rrrlJeXp5qaGh06dEgjIyMaGRnRoUOHVFNTk+pxAQAplrRPYBs2bNArr7yi4eFh\
# 2e12bd++XefPn5ckfetb39KaNWv00ksvyeFwaM6cOXrmmWckSTk5OXrsscdUVlYmSWpqarroj0EA\
# AFcHS2yyL5kyAJcQAeDymfTemTaXEAEAuBwEDABgJAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEw\
# AICRCBgAwEgEDABgJAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICRCBgAwEgEDAB
AEAjETAAABGImAAACMRMACAkQgYAMBIBAwAYCQCBgAwEgED\
# ABiJgAEAjETAAABGImAAACMRMACAkQgYAMBIBAwAYCQCBgAwEgEDABiJgAEAjGRZwLq6ulRcXCyn\
# 06mWlpYJ+zdv3iy32y23260FCxZo3rx5iX0zZ85M7PN6vVaNDABIY3YrXiQWi2nTpk3q7u6Ww+FQ\
# ZWWlvF6vSktLE2t+8pOfJP787LPP6ujRo4nHc+bMUW9vrxWjAgAMYcknsJ6eHjmdThUVFWnWrFmq\
# r69XR0fHlOtbW1u1bt06K0YDABjKkoCFw2EVFhYmHjscDoXD4UnXvvfee+rr69Py5csT286fPy+P\
# x6Oqqiq1t7cnfV4AQPqz5BJiPB6fsM1ms026tq2tTXV1dZo5c2Zi2/vvv6+CggIdP35cy5cvV3l5\
# uW655ZYJx/r9fvn9fknS0NDQNE0PAEhHlnwCczgcGhgYSDweHBxUQUHBpGvb2tomXD78eG1RUZGW\
# Ll067vux/+Tz+RQMBhUMBpWbmztN0wMA0pElAausrFQoFFJfX5+i0aja2tom/TXhu+++q5GREd15\
# 552JbSMjIxobG5MkDQ8P6/Dhw+N+/AEAuDZZcgnRbrdr165dqq2tVSwWU2Njo8rKytTc3CyPx5OI\
# WWtrq+rr68ddXnznnXf0yCOPaMaMGfroo4/U1NREwAAAssUn+4IqA3g8HgWDwVSPAQBGMem9kztx\
# AACMRMAAAEYiYAAAIxEwAICRCBgAwEgEDABgJAIGADASAQMAGImAAQCMRMAAAEYiYAAAIxEwAICR\
# CBgAwEgEDABgJAIGADASAQMAGImAAQCMRMAAAEayNGBdXV0qLi6W0+lUS0vLhP0vv

# %% [markdown]
# **(Optional) Exercise 6** Make an animation tracing out the position and velocity of the nonlinear oscillator you simulated above.

# %%
tnl,xnl,vnl = EulerCromerDuffing(20,dt/2.,w0=w0,x0=0.9,epsilon=10)

fig, ax = plt.subplots()
ax.plot(xnl,vnl)
ax.lines[0].remove()
l1, = ax.plot([],[],'-')
l2, = ax.plot([],[],'ko')
plt.close(fig)

def animate(i):
    l1.set_data(xnl[:i], vnl[:i])
    l2.set_data(xnl[i-1],vnl[i-1])
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(t))

HTML(ani.to_jshtml())
# Out:
# Natural frequency 1.00
# Number of oscillations per time step: 1/w_osc*dt = 20.000
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0d4e8caa5477415f8ac816fb29f35a7c">
#     <br>
#     <input id="_anim_slider0d4e8caa5477415f8ac816fb29f35a7c" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0d4e8caa5477415f8ac816fb29f35a7c.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0d4e8caa5477415f8ac816fb29f35a7c.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0d4e8caa5477415f8ac816fb29f35a7c" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0d4e8caa5477415f8ac816fb29f35a7c";
#     var slider_id = "_anim_slider0d4e8caa5477415f8ac816fb29f35a7c";
#     var loop_select_id = "_anim_loop_select0d4e8caa5477415f8ac816fb29f35a7c";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAGOhJREFUeJzt3X9s1PXhx/HXwQ0mcyCFVnu5GihX\
# sD8oDVylJo5AoXZAOMao/AiRIswDgzFhiYOEjOlCR022ZTPglgsI1ZF2A5USB5Vf4h8E7W5C3MC4\
# Dgq0RwttKY7poNC9v3/45ULXK4LS+9wbno+EpJ/35/25e+XD5V79vO8D5zLGGAEAYJk+TgcAAODr\
# oMAAAFaiwAAAVqLAAABWosAAAFaiwAAAVqLAAABWosAAAFaiwAAAVqLAAABWosAAAFaiwAAAVq